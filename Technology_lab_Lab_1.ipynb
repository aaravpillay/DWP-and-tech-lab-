# %% [markdown]
# <a href="https://colab.research.google.com/github/aaravpillay/DWP-and-tech-lab-/blob/main/Technology_lab_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import pandas as pd
import statsmodels.api as sm
# Import Gaussain Naive Bayes model
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.metrics import classification_report

# %%
#IRIS DATASET
iriss = datasets.load_iris()
iris = pd.DataFrame(iriss.data)
iris.columns = iriss.feature_names
iris['Species'] = iriss.target
iris.coloumns = iris.columns.str.replace(" ","")
iris.coloumns = iris.columns.str.replace("(","")
iris.coloumns = iris.columns.str.replace(")","")
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Target Column Distribution
iris['Species'].value_counts()  #all equal values so we can use further classification
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
# Distribution (mean) of Independent Columns respect to Dependent Column
iris.groupby('Species').mean().round(2)
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Species
# 0                     5.01              3.43               1.46
# 1                     5.94              2.77               4.26
# 2                     6.59              2.97               5.55
#
#          petal width (cm)
# Species
# 0                    0.25
# 1                    1.33
# 2                    2.03

# %%
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
# Independent Variables
Independent_Variable_Base_Set = iris[iris.columns[0:4]]
Independent_Variable_Base_Set.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Dependent Variables
Dependent_Variable_Base_Set = iris[iris.columns[-1:iris.columns.size]]
Dependent_Variable_Base_Set.head()
# Out:
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Split the Dataset

# Model 1
# Lets start with selecting one variable
Independent_Variable_Set_v1 = iris[iris.columns[0:1]]
X_train, X_test, y_train , y_test = train_test_split(Independent_Variable_Set_v1,Dependent_Variable_Base_Set,test_size=0.3,random_state=21)

# Create a Gaussian Classifier
model = GaussianNB()

# Train the model using the training sets
result = model.fit(X_train,y_train)

dir(result)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_X',
#  '_check_feature_names',
#  '_check_n_features',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_joint_log_likelihood',
#  '_more_tags',
#  '_parameter_constraints',
#  '_partial_fit',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_update_mean_variance',
#  '_validate_data',
#  '_validate_params',
#  'class_count_',
#  'class_prior_',
#  'classes_',
#  'epsilon_',
#  'feature_names_in_',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'n_features_in_',
#  'partial_fit',
#  'predict',
#  'predict_joint_log_proba',
#  'predict_log_proba',
#  'predict_proba',
#  'priors',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_partial_fit_request',
#  'set_score_request',
#  'theta_',
#  'var_',
#  'var_smoothing']

# %%
pred = result.predict(X_test)
pred
# Out:
# array([1, 0, 0, 0, 1, 2, 0, 1, 0, 0, 1, 1, 2, 2, 0, 2, 1, 1, 1, 1, 2, 1,
#        1, 2, 0, 0, 0, 0, 2, 2, 0, 2, 1, 0, 1, 2, 1, 1, 0, 1, 1, 2, 1, 1,
#        2])

# %%
# Model Prediction
model_prediction = pd.DataFrame(pred.round(2),columns=['Prediction'])
print(model_prediction['Prediction'].head())
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Prediction, dtype: int64

# %%
# Test Set Target Column Distribution
print("\nTest Set Distribution")
print(y_test['Species'].value_counts())
# Out:
# Test Set Distribution
# Species
# 1    16
# 2    15
# 0    14
# Name: count, dtype: int64

# %%
# Predicted Set Target Column Distribution
print("\nPredicted Set Distribution")
print(model_prediction['Prediction'].value_counts())
# Out:
# Predicted Set Distribution
# Prediction
# 1    19
# 0    14
# 2    12
# Name: count, dtype: int64

# %%
# Model Performance
y_pred = model_prediction[['Prediction']]
model_1_accuracy = accuracy_score(y_test,y_pred)
print("Model 1 Performance")
print("Accuracy Score: ",model_1_accuracy)
model_1_precision = precision_score(y_test,y_pred,average='micro')
print("Precision Score: ",model_1_precision)
model_1_recall = recall_score(y_test,y_pred,average='micro')
print("Recall Score: ",model_1_recall)
model_1_fscore = f1_score(y_test,y_pred,average='micro')
print("F1 Score: ",model_1_fscore)
print("\nConfusion Matrix")
model_1_cm = confusion_matrix(y_test,y_pred)
print(model_1_cm)
print("\nClassification Report, Model 1")
model_1_cr = classification_report(y_test,y_pred)
print(model_1_cr)

print("Inference : Good Fit,can we make it better ?")
# Out:
# Model 1 Performance
# Accuracy Score:  0.6666666666666666
# Precision Score:  0.6666666666666666
# Recall Score:  0.6666666666666666
# F1 Score:  0.6666666666666666
#
# Confusion Matrix
# [[13  1  0]
#  [ 1 10  5]
#  [ 0  8  7]]
#
# Classification Report, Model 1
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        14
#            1       0.53      0.62      0.57        16
#            2       0.58      0.47      0.52        15
#
#     accuracy                           0.67        45
#    macro avg       0.68      0.67      0.67        45
# weighted avg       0.67      0.67      0.66        45
#
# Inference : Good Fit,can we make it better ?

# %%
# Model 2
# Lets build model with all variables

X_train,X_test,y_train,y_test = train_test_split(Independent_Variable_Base_Set,Dependent_Variable_Base_Set,test_size=0.3,random_state=21)
# Train the model using the training sets
result = model.fit(X_train,y_train)

# Model Prediction
print("Sample Prediction of Model 2")
pred = result.predict(X_test)
model_prediction = pd.DataFrame(pred.round(2),columns=['Prediction'])
print(model_prediction['Prediction'].head())

# Test Set Target Column Distribution
print("\nTest Set Distribution")
print(y_test['Species'].value_counts())

# Predicted Set Target Column Distribution
print("\nPredicted Set Distribution")
print(model_prediction['Prediction'].value_counts())

# Model Performance
y_pred = model_prediction[['Prediction']]
model_1_accuracy = accuracy_score(y_test,y_pred)
print("Model 1 Performance")
print("Accuracy Score: ",model_1_accuracy)
model_1_precision = precision_score(y_test,y_pred,average='micro')
print("Precision Score: ",model_1_precision)
model_1_recall = recall_score(y_test,y_pred,average='micro')
print("Recall Score: ",model_1_recall)
model_1_fscore = f1_score(y_test,y_pred,average='micro')
print("F1 Score: ",model_1_fscore)
print("\nConfusion Matrix")
model_1_cm = confusion_matrix(y_test,y_pred)
print(model_1_cm)
print("\nClassification Report, Model 1")
model_1_cr = classification_report(y_test,y_pred)
print(model_1_cr)

print("Inference : Good Fit,can we make it better ?")
# Out:
# Sample Prediction of Model 2
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Prediction, dtype: int64
#
# Test Set Distribution
# Species
# 1    16
# 2    15
# 0    14
# Name: count, dtype: int64
#
# Predicted Set Distribution
# Prediction
# 2    17
# 1    14
# 0    14
# Name: count, dtype: int64
# Model 1 Performance
# Accuracy Score:  0.9555555555555556
# Precision Score:  0.9555555555555556
# Recall Score:  0.9555555555555556
# F1 Score:  0.9555555555555556
#
# Confusion Matrix
# [[14  0  0]
#  [ 0 14  2]
#  [ 0  0 15]]
#
# Classification Report, Model 1
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.88      0.93        16
#            2       0.88      1.00      0.94        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# Inference : Good Fit,can we make it better ?
